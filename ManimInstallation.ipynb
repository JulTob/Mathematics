# %% [markdown]
# <a href="https://colab.research.google.com/github/JulTob/Mathematics/blob/master/ManimInstallation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Manim
# Mathematical Animations.

# %% [markdown]
# # Colab Installation

# %%
# (1) Paquetes del sistema para Cairo/Pango + toolchain
# !sudo apt-get update -y
# !sudo apt-get install -y \
  build-essential pkg-config ninja-build \
  libcairo2-dev libpango1.0-dev libglib2.0-dev libharfbuzz-dev \
  ffmpeg
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 https://cli.github.com/packages stable InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# %pip install -U pip wheel
# %pip install -U manim manimpango pycairo
# %load_ext manim
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# The manim module is not an IPython extension.

# %%
# !sudo apt-get install -y texlive-latex-extra texlive-fonts-extra texlive-pictures texlive-science texlive-latex-recommended
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libbz2-dev libpkgconf3 libreadline-dev
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   dvisvgm fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-cabin fonts-cantarell fonts-comfortaa
#   fonts-croscore fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu-core fonts-dejavu-extra fonts-droid-fallback fonts-ebgaramond
#   fonts-ebgaramond-extra fonts-font-awesome fonts-freefont-otf
#   fonts-freefont-ttf fonts-gfs-artemisia fonts-gfs-baskerville
#   fonts-gfs-complutum fonts-gfs-didot fonts-gfs-neohellenic fonts-gfs-olga
#   fonts-gfs-porson fonts-gfs-solomos fonts-go fonts-junicode fonts-lato
#   fonts-linuxlibertine fonts-lmodern fonts-lobster fonts-lobstertwo
# ...

# %%
# %%manim -v WARNING -qm --renderer=cairo Hello
# from manim import *
# class Hello(Scene):
#     def construct(self):
#         self.play(Write(Text("Manim")))
#         self.wait(5.5)
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Examples

# %% [markdown]
# ## Write text

# %%
from manim import *
class Hello(Scene):
    def construct(self):
        self.play(Write(Text("Cool Story Bro")))
        self.wait(5.5)

# %%
# %%manim -v WARNING -qm --renderer=cairo Hello
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Create Shapes

# %%
class CreateCircle(Scene):
    def construct(self):
        circle = Circle()
            # create a circle object
        circle.set_fill(RED, opacity=0.5)
            # set the color and transparency
        self.play(Create(circle))
            # show the circle on screen

# %%
# %%manim -v WARNING -qm --renderer=cairo CreateCircle
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class CreateShapes(Scene):
    def construct(self):
        circle = Circle()
        # create a circle
        circle.set_fill(RED, opacity=0.5)
        # set color and transparency

        square = Square()
        # create a square
        square.rotate(PI / 4)
        # Set the rotation to a initial amount

        self.play(Create(square))
        # animate the creation of the square
        self.play(Transform(square, circle))
        # interpolate the square into the circle
        self.play(FadeOut(square))
        # fade out animation

# %%
# %%manim -v WARNING -qm --renderer=cairo CreateShapes
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Positioning

# %%
class SquareAndCircle(Scene):
    def construct(self):
        circle = Circle()
        # create a circle
        circle.set_fill(RED, opacity=0.5)
        # set the color and transparency

        square1 = Square()
        square2 = Square()
        square3 = Square()
        square4 = Square()
        # create squares
        square1.set_fill(BLUE, opacity=0.5)
        square2.set_fill(GREEN, opacity=0.5)
        square3.set_fill(ORANGE, opacity=0.5)
        square4.set_fill(GOLD, opacity=0.5)
        # set the color and transparency

        square1.next_to(circle, UP, buff=0.5)
        square2.next_to(circle, DOWN, buff=0.8)
        square3.next_to(circle, LEFT, buff=2.5)
        square4.next_to(circle, RIGHT, buff=1.7)
        # set the position
        self.play(Create(circle),
                  Create(square1),
                  Create(square2),
                  Create(square3),
                  Create(square4)
                  )  # show the shapes on screen

# %%
# %%manim -v WARNING -qm --renderer=cairo SquareAndCircle
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class AnimatedSquareToCircle(Scene):
    def construct(self):
        circle = Circle()
        # create a circle
        square = Square()
        # create a square

        self.play(Create(square))
        # show the square on screen
        self.play(square.animate.rotate(PI / 4))
        # rotate the square
        self.play(Transform(square, circle))
        # transform the square into a circle
        self.play(
            circle.animate.set_fill(RED, opacity=0.5)
        )  # color the circle on screen
        self.play(circle.animate.flip(UP))
        # flip the circle vertically
        self.play(circle.animate.shift(RIGHT * 2))
        # shift the circle to the right

# %%
# %%manim -v WARNING -qm --renderer=cairo AnimatedSquareToCircle
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class DifferentRotations(Scene):
    def construct(self):
        left_square = Square(color=BLUE, fill_opacity=0.7).shift(2 * LEFT)
        right_square = Square(color=GREEN, fill_opacity=0.7).shift(2 * RIGHT)
        self.play(
            left_square.animate.rotate(PI),
            Rotate(right_square, angle=PI),
            run_time=2
            )
        self.wait()

# %%
# %%manim -v WARNING -qm --renderer=cairo DifferentRotations
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Transformations

# %% [markdown]
# The difference between Transform and ReplacementTransform is that Transform(mob1, mob2) transforms the points (as well as other attributes like color) of mob1 into the points/attributes of mob2.
#
# ReplacementTransform(mob1, mob2) on the other hand literally replaces mob1 on the scene with mob2.

# %%
class TwoTransforms(Scene):
    def transform(self):
        a = Circle()
        b = Square()
        c = Triangle()
        self.play(Transform(a, b))
        self.play(Transform(a, c))
        self.play(FadeOut(a))

    def replacement_transform(self):
        a = Circle()
        b = Square()
        c = Triangle()
        self.play(ReplacementTransform(a, b))
        self.play(ReplacementTransform(b, c))
        self.play(FadeOut(c))

    def construct(self):
        self.transform()
        self.wait(0.5)  # wait for 0.5 seconds
        self.replacement_transform()
        self.wait(0.5)  # wait for 0.5 seconds

# %%
# %%manim -v WARNING -qm --renderer=cairo TwoTransforms
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Composit Structures

# %%
class Slider(VGroup):
    def __init__(struct, start=LEFT * 3, end=RIGHT * 3, color=WHITE, dot_color=RED, **kwargs):
        super().__init__(**kwargs)
        struct.line_start = start
        struct.line_end = end
        struct.slider_line = Line(struct.line_start, struct.line_end, color=color)
        struct.slider_dot = Dot(color=dot_color).scale(2)
        struct.add(struct.slider_line, struct.slider_dot)
        struct.Set(0) # Initialize dot at the start

    def Position(self, proportion ):
        """
        Retourns the position point at proportion.
        """
        start = self.slider_line.get_start()
        end = self.slider_line.get_end()
        interpoint = (1-proportion) * start + proportion * end
        return interpoint

    def Set(self, proportion):
        """
        Moves the slider dot to a position along the line based on a proportion (0 to 1).
        """
        return self.slider_dot.animate.move_to(self.Position(proportion))


    def Slide(self, proportion, **kwargs):
        """
        Animates the slider dot to a position along the line based on a proportion (0 to 1).
        """
        return self.slider_dot.animate(**kwargs).move_to(self.Position(proportion))

    def get_proportion(self):
        """
        Gets the current proportion (0 to 1) of the slider dot along the line.
        """
        start = self.slider_line.get_start()
        end = self.slider_line.get_end()
        current_position = self.slider_dot.get_center()
        # Calculate the projection of the dot's position onto the line
        line_vector = end - start
        dot_vector = current_position - start
        projection = np.dot(dot_vector, line_vector) / np.dot(line_vector, line_vector)
        # Clamp the proportion between 0 and 1
        proportion = max(0, min(1, projection))
        return proportion

    def get_value(self, min_value, max_value):
        """
        Gets the current value of the slider based on its proportion and a value range.
        """
        proportion = self.get_proportion()
        return min_value + proportion * (max_value - min_value)

# %%
class SliderExample(Scene):
    def construct(self):
        # Create a horizontal slider
        horizontal_slider = Slider(start=LEFT * 4, end=RIGHT * 4)
        self.play(Create(horizontal_slider))
        self.play(horizontal_slider.Slide(0.175, run_time=2))
        self.play(horizontal_slider.Set(0.75))
        self.play(horizontal_slider.Set(0.2))
        self.play(horizontal_slider.Slide(0.72, run_time=2))
        self.wait()

        # Create a vertical slider
        vertical_slider = Slider(start=DOWN * 3, end=UP * 3, color=BLUE, dot_color=YELLOW)
        self.play(Create(vertical_slider))
        self.play(vertical_slider.Slide(0.5, run_time=2))
        self.play(vertical_slider.Slide(1, run_time=2))
        self.play(vertical_slider.Set(0.5))
        self.play(vertical_slider.Set(1))
        self.wait()

        # Create another horizontal slider and position it
        another_slider = Slider(start=LEFT * 2, end=RIGHT * 2, color=GREEN, dot_color=PURPLE)
        another_slider.shift(DOWN * 2)
        self.play(Create(another_slider))
        self.play(another_slider.Set(0.1))
        self.play(another_slider.Slide(0.9, run_time=2))
        self.play(another_slider.Slide(0.5, run_time=2))
        self.wait()

# %%
# %%manim -v WARNING -qm --renderer=cairo SliderExample
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Linking

# %%
class LinkedSlidersExample(Scene):
    def construct(self):
        # Create a slider
        slider = Slider(start=LEFT * 3, end=RIGHT * 3, color=BLUE, dot_color=RED)
        slider.shift(UP)

        # Add a label to the slider
        label_slider = Text("Value:").next_to(slider, LEFT)

        # Create a DecimalNumber to display the slider's value
        value_display = DecimalNumber(
            slider.get_value(0, 10),  # Initial value
            num_decimal_places=2
        ).next_to(slider, RIGHT)

        self.play(Create(VGroup(slider, label_slider, value_display)))

        # Link the value_display to the slider's value
        def update_value_display(mob):
            mob.set_value(slider.get_value(0, 10)) # Update the value based on the slider (range 0 to 10)
            mob.next_to(slider, RIGHT) # Keep the text next to the slider

        value_display.add_updater(update_value_display)


        # Demonstrate changing the slider and seeing the value display update
        self.play(slider.Slide(0.2, run_time=2))
        self.play(slider.Slide(0.8, run_time=2))
        self.play(slider.Slide(0.5, run_time=2))

        self.wait()

        # Example with a different range
        self.play(FadeOut(VGroup(label_slider, value_display)))

        label_slider_2 = Text("Theta:").next_to(slider, LEFT)
        theta_display = DecimalNumber(
            slider.get_value(0, 2 * PI),  # Initial value (range 0 to 2*PI)
            num_decimal_places=2
        ).next_to(slider, RIGHT)

        self.play(Create(VGroup(label_slider_2, theta_display)))

        def update_theta_display(mob):
            mob.set_value(slider.get_value(0, 2 * PI)) # Update the value based on the slider (range 0 to 2*PI)
            mob.next_to(slider, RIGHT) # Keep the text next to the slider

        theta_display.add_updater(update_theta_display)

        self.play(slider.Slide(0.1, run_time=2))
        self.play(slider.Slide(0.9, run_time=2))
        self.play(slider.Slide(0.4, run_time=2))

        self.wait()

# %%
# %%manim -v WARNING -qm --renderer=cairo LinkedSlidersExample
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
